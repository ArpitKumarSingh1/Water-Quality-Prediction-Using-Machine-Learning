# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv(r'E:\Dataset\water_potability.csv')

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
data.shape  #Rows,Columns
# Out:
# (3276, 10)

# %%
print(data.columns)
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
data.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
data['ph']>7
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 3271    False
# 3272     True
# 3273     True
# 3274    False
# 3275     True
# Name: ph, Length: 3276, dtype: bool

# %%
data[data['ph']>7]
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 2      8.099124  224.236259  19909.541732     9.275884         NaN
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 7      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3272   7.808856  193.553212  17329.802160     8.061362         NaN
# 3273   9.419510  175.762646  33155.578218     7.350233         NaN
# 3275   7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2       418.606213       16.868637        66.420093   3.055934           0
# ...

# %%
data[data['ph']<=3]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 80    1.844538  233.764343  28689.595778     7.724432         NaN
# 104   2.612036  188.804126  34798.252587     6.796439         NaN
# 354   2.798549  311.383956  26931.243483     7.116897         NaN
# 692   1.757037  147.581831  41538.242730     7.728177  376.012933
# 726   0.227499  152.530111  39028.599340     3.462492  283.693782
# 810   0.989912  133.216942  16922.853899     9.293289  444.375731
# 1231  2.690831  151.782906  30204.546735     6.053072  303.702409
# 1343  2.569244  201.603284  48204.172192     6.380684  261.719960
# 2165  2.803563  186.123924  11920.907422     8.642034  332.744519
# 2189  2.558103  147.490575  21316.506728     9.142234  312.054239
# 2300  2.974429  147.148675  17326.202253     2.498597  393.168745
# 2343  2.538116  100.806520  19872.854854     5.014023  418.000000
# 2473  2.945469  126.748100  16829.393039    10.597395         NaN
# ...

# %%
data[data['ph']>3]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# 5     5.584087  188.313324  28748.687739     7.544869  326.678363
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 1       592.885359       15.180013        56.329076   4.500656           0
# ...

# %%
data[data['Conductivity']<400]
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 8           NaN  118.988579  14285.583854     7.804174  268.646941
# ...         ...         ...           ...          ...         ...
# 3257   6.683368  272.111698  18989.316768     5.336202  336.555100
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3272   7.808856  193.553212  17329.802160     8.061362         NaN
# 3275   7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3       363.266516       18.436524       100.341674   4.628771           0
# ...

# %%
data[data['Conductivity']>250]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
data[data['Sulfate']<250]
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 51     7.809632  100.457615  12013.550629     5.212315  247.200826
# 118    7.397413  122.541040   8855.114121     6.888689  241.607532
# 130    6.643936  151.889600  10909.194592     3.749625  240.936722
# 227    7.083779  112.820254   8580.245561     4.210284  234.852699
# 253    6.800119  242.008082  39143.403329     9.501695  187.170714
# 270    7.291888  127.544297  27784.048484     9.754476  247.335412
# 272    6.512737  229.263861  22475.046873    12.580026  192.033592
# 275    5.324942  280.089655  35344.658047    13.043806  180.206746
# 281    8.210444  167.102192  13933.085360    10.422842  243.485942
# 310         NaN  273.255621  44506.441561     8.412688  233.792588
# 351    8.848586  188.919983  32033.332019    13.127000  182.397370
# 357    7.748655  239.788278  29331.236633    10.713097  217.000607
# 365    4.788861  234.893703  28174.620516    10.850036  187.424131
# ...

# %%
data[data['Sulfate']>250]
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 0           NaN  204.890455  20791.318981     7.300212  368.516441
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# ...         ...         ...           ...          ...         ...
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
data[data['Organic_carbon']<4.5]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 785   5.140801  209.358561  21407.614287     4.415976  230.555856
# 1390  7.593177  201.068737  19214.186357     7.710120  351.386080
# 1663       NaN  204.384794  32951.316369     5.995277  324.505190
# 2224  6.001382  186.884422  22554.830087     8.391883  331.214867
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 785     378.897190        2.200000        86.737223   4.192257           1
# 1390    451.211449        4.371899        74.673986   3.542093           0
# 1663    339.641882        4.473092        71.190496   4.905230           0
# 2224    444.891044        4.466772        65.954766   4.036720           0

# %%
data[data['Trihalomethanes']<=80]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# 5     5.584087  188.313324  28748.687739     7.544869  326.678363
# 7     8.635849  203.361523  13672.091764     4.563009  303.309771
# ...        ...         ...           ...          ...         ...
# 3270  6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 1       592.885359       15.180013        56.329076   4.500656           0
# ...

# %%
data[data['Turbidity']<5.00]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
data[data['Chloramines']>4]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# # Data Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
print(data.nunique())
# Out:
# ph                 2785
# Hardness           3276
# Solids             3276
# Chloramines        3276
# Sulfate            2495
# Conductivity       3276
# Organic_carbon     3276
# Trihalomethanes    3114
# Turbidity          3276
# Potability            2
# dtype: int64

# %%
df.isnull().mean().plot.bar(figsize=(10,6)) 
plt.ylabel('Percentage of missing values') 
plt.xlabel('Features') 
plt.title('Missing Data in Percentages');

# %%
data.dtypes
# Out:
# ph                 float64
# Hardness           float64
# Solids             float64
# Chloramines        float64
# Sulfate            float64
# Conductivity       float64
# Organic_carbon     float64
# Trihalomethanes    float64
# Turbidity          float64
# Potability           int64
# dtype: object

# %%
data.fillna(data.mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# # Exporatory Data Analysis

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.469956    32.879761   8768.570828     1.583085    36.142612
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.080795   196.967627  20927.833607     7.130299   333.775777
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        15.769881     0.780382     0.487849
# ...

# %% [markdown]
# ### Checking if we need to do Dimensonality Reduction

# %%
data.corr()  #correlation coefficent
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.075833 -0.081884    -0.031811  0.014403
# Hardness         0.075833  1.000000 -0.046899    -0.030054 -0.092766
# Solids          -0.081884 -0.046899  1.000000    -0.070148 -0.149840
# Chloramines     -0.031811 -0.030054 -0.070148     1.000000  0.023791
# Sulfate          0.014403 -0.092766 -0.149840     0.023791  1.000000
# Conductivity     0.017192 -0.023915  0.013831    -0.020486 -0.014059
# Organic_carbon   0.040061  0.003610  0.010242    -0.012653  0.026909
# Trihalomethanes  0.002994 -0.012690 -0.008875     0.016627 -0.025605
# Turbidity       -0.036222 -0.014449  0.019546     0.002363 -0.009790
# Potability      -0.003287 -0.013837  0.033743     0.023779 -0.020619
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity  \
# ph                   0.017192        0.040061         0.002994  -0.036222
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(data.corr(),annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# Unstacking the correlation matrix to see the values more clearly.
corr = data.corr()
c1 = corr.abs().unstack()
c1.sort_values(ascending = False)[12:24:2]
# Out:
# Hardness  Sulfate           0.092766
# ph        Solids            0.081884
# Hardness  ph                0.075833
# Solids    Chloramines       0.070148
# Hardness  Solids            0.046899
# ph        Organic_carbon    0.040061
# dtype: float64

# %% [markdown]
# ### Lets check the Outlier using Box Ploat

# %%
data.boxplot(figsize=(15,6))
plt.show()

# %%
data['Solids'].describe()
# Out:
# count     3276.000000
# mean     22014.092526
# std       8768.570828
# min        320.942611
# 25%      15666.690297
# 50%      20927.833607
# 75%      27332.762127
# max      61227.196008
# Name: Solids, dtype: float64

# %%
data['Solids']
# Out:
# 0       20791.318981
# 1       18630.057858
# 2       19909.541732
# 3       22018.417441
# 4       17978.986339
#             ...
# 3271    47580.991603
# 3272    17329.802160
# 3273    33155.578218
# 3274    11983.869376
# 3275    17404.177061
# Name: Solids, Length: 3276, dtype: float64

# %%
data.shape
# Out:
# (3276, 10)

# %%
data['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
sns.countplot(data['Potability'])
plt.show()

# %%
sns.violinplot(x='Potability', y='ph', data=data, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='ph'>

# %%
# Visualizing dataset and also checking for outliers 

fig, ax = plt.subplots(ncols = 5, nrows = 2, figsize = (20, 10))
index = 0
ax = ax.flatten()

for col, value in data.items():
    sns.boxplot(y=col, data=data, ax=ax[index])
    index += 1
plt.tight_layout(pad = 0.5, w_pad=0.7, h_pad=5.0)

# %%
sns.distplot(data['ph'])
plt.show()
# Out:
# C:\Users\ARPIT KUMAR SINGH\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data.hist(figsize=(14,12))
plt.show()

# %%
sns.pairplot(data,hue='Potability')

# %%
plt.rcParams['figure.figsize'] = [7,5]
sns.distplot(data['Potability'])
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Density'>

# %%
data.hist(column='ph', by='Potability')
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %%
data.hist(column='Hardness', by='Potability')
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %%
sns.histplot(x = "Hardness", data=data)
# Out:
# <AxesSubplot:xlabel='Hardness', ylabel='Count'>

# %%
# Individual box plot for ph
def Box(data):
    plt.title("Box Plot")
    sns.boxplot(data)
    plt.show()
Box(data['ph'])

# %%
 sns.scatterplot(data['Hardness'],data['Solids'])
# Out:
# C:\Users\ARPIT KUMAR SINGH\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Hardness', ylabel='Solids'>

# %%
sns.scatterplot(x=data['ph'],y=data['Potability'])
plt.show()

# %%
y = np.array([43.25,56.75])
mylabels = ["ph>7", "ph<7"]
mycolors = ["blue", "red"]
plt.pie(y, labels = mylabels,colors=mycolors,shadow=True)
plt.legend(title = "ph values:")
plt.show()

# %%
y = np.array([0.71,48.40,47.14,3.75])
mylabels = ["ph<=3", "3<ph<=7","7<ph<=10","ph>10"]
mycolors = ["red", "blue","green","orange"]
myexplode = [0, 0, 0, 0.5]
plt.pie(y, labels = mylabels,startangle = 145,explode = myexplode,colors=mycolors,shadow=True)
plt.legend(title = "ph values:")
plt.show()

# %%
y = np.array([2.71,97.29])
mylabels = ["<=4ppm.safe for drinking", ">4ppm.non-drinkable"]
mycolors = ["green","orange"]
myexplode = [0, 0.5]
plt.pie(y, labels = mylabels,explode = myexplode,colors=mycolors,shadow=True)
plt.legend(title ="chloramines:")
plt.show()

# %%
y = np.array([40.11,59.89])
mylabels = ["<=400.safe for drinking", ">400.non-drinkable"]
mycolors = ["green","blue"]
myexplode = [0, 0.1]
plt.pie(y, labels = mylabels,explode = myexplode,colors=mycolors,shadow=True)
plt.legend(title ="Conductivity:")
plt.show()

# %%
y = np.array([2.36,97.67])
mylabels = ["<=250.safe for drinking", ">250.non-drinkable"]
mycolors = ["red","yellow"]
myexplode = [0, 0.1]
plt.pie(y, labels = mylabels,explode = myexplode,colors=mycolors,shadow=True)
plt.legend(title ="Sulfates:")
plt.show()

# %%
y = np.array([0.122,99.88])
mylabels = ["<=4.5.safe for drinking", ">4.5.non-drinkable"]
mycolors = ["green","orange"]
myexplode = [0, 0.6]
plt.pie(y, labels = mylabels,explode = myexplode,colors=mycolors,shadow=True)
plt.legend(title ="Organic_carbon:")
plt.show()

# %%
y = np.array([80.67,19.33])
mylabels = ["<=80.safe for drinking", ">80.non-drinkable"]
mycolors = ["blue","red"]
myexplode = [0, 0.6]
plt.pie(y, labels = mylabels,explode = myexplode,colors=mycolors,shadow=True)
plt.legend(title ="Trihalomethanes:")
plt.show()

# %%
y = np.array([90.42,9.58])
mylabels = ["<=5.safe for drinking", ">5.non-drinkable"]
mycolors = ["violet","yellow"]
myexplode = [0, 0.6]
plt.pie(y, labels = mylabels,explode = myexplode,colors=mycolors,shadow=True)
plt.legend(title ="Turbidity:")
plt.show()

# %% [markdown]
# # Partitioning

# %%
x=data.drop('Potability', axis=1)  #Input data

# %%
y=data['Potability']  #Target variable

# %%
x.shape, y.shape
# Out:
# ((3276, 9), (3276,))

# %%
# import StandardScaler to perform scaling
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()

# %%
x = scaler.fit_transform(x)
x
# Out:
# array([[-1.02733269e-14,  2.59194711e-01, -1.39470871e-01, ...,
#         -1.18065057e+00,  1.30614943e+00, -1.28629758e+00],
#        [-2.28933938e+00, -2.03641367e+00, -3.85986650e-01, ...,
#          2.70597240e-01, -6.38479983e-01,  6.84217891e-01],
#        [ 6.92867789e-01,  8.47664833e-01, -2.40047337e-01, ...,
#          7.81116857e-01,  1.50940884e-03, -1.16736546e+00],
#        ...,
#        [ 1.59125368e+00, -6.26829230e-01,  1.27080989e+00, ...,
#         -9.81329234e-01,  2.18748247e-01, -8.56006782e-01],
#        [-1.32951593e+00,  1.04135450e+00, -1.14405809e+00, ...,
#         -9.42063817e-01,  7.03468419e-01,  9.50797383e-01],
#        [ 5.40150905e-01, -3.85462310e-02, -5.25811937e-01, ...,
#          5.60940070e-01,  7.80223466e-01, -2.12445866e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, shuffle=True, random_state=101)

# %%
y_test
# Out:
# 2541    0
# 2605    0
# 330     1
# 515     0
# 400     1
#        ..
# 482     0
# 2970    0
# 50      0
# 839     0
# 374     1
# Name: Potability, Length: 656, dtype: int64

# %%
x_train
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 748   6.750761  207.254505  23642.992597     7.691012  293.783040
# 2279  7.539742  201.959317  26716.359708     5.637350  333.775777
# 1960  8.128270  231.167537  19954.575554     5.138838  349.067363
# 1491  7.368166  204.041451   8524.874646     9.469763  429.814322
# 2991  6.628256  198.865743  15911.357509     7.517906  342.015924
# ...        ...         ...           ...          ...         ...
# 599   7.080795  205.638790  39742.970329     4.660528  323.956492
# 1599  8.227083  274.351887  40546.956332     7.130161  241.446917
# 1361  4.906492  173.779159  14786.138901     5.843757  267.561144
# 1547  6.217585  203.707222  15597.640883     7.751461  361.247810
# 863   7.685397  230.335708   7324.701425     7.991366  331.512533
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 748     446.696939        6.000391        30.900815   2.777726
# ...

# %% [markdown]
# # Model Training

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(metric='manhattan', n_neighbors=22)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=22)

# %%
prediction_knn=knn.predict(x_test)
kn=accuracy_score(y_test,prediction_knn)*100
print('accuracy_score score       :  ',accuracy_score(y_test,prediction_knn)*100,'%')
# Out:
# accuracy_score score       :   61.737804878048784 %

# %%
print(classification_report(y_test,pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.82      0.71       402
#            1       0.45      0.24      0.31       254
#
#     accuracy                           0.59       656
#    macro avg       0.54      0.53      0.51       656
# weighted avg       0.56      0.59      0.56       656

# %%
cm5=confusion_matrix(prediction_knn,y_test)
sns.heatmap(cm5/np.sum(cm5), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Using Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Creating model object
model_lg = LogisticRegression(max_iter=120,random_state=0, n_jobs=20)

# %%
# Training Model
model_lg.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=120, n_jobs=20, random_state=0)

# %%
# Making Prediction
pred_lg = model_lg.predict(x_test)

# %%
# Calculating Accuracy Score
lg = accuracy_score(y_test, pred_lg)*100
print(lg)
# Out:
# 61.28048780487805

# %%
print(classification_report(y_test,pred_lg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       402
#            1       0.00      0.00      0.00       254
#
#     accuracy                           0.61       656
#    macro avg       0.31      0.50      0.38       656
# weighted avg       0.38      0.61      0.47       656

# %%
# confusion Maxtrix
cm1 = confusion_matrix(y_test, pred_lg)
sns.heatmap(cm1/np.sum(cm1), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Using Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Creating model object
model_dt = DecisionTreeClassifier( max_depth=4, random_state=42)

# %%
# Training Model
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
# Making Prediction
pred_dt = model_dt.predict(x_test)

# %%
# Calculating Accuracy Score
dt = accuracy_score(y_test, pred_dt)*100
print(dt)
# Out:
# 63.71951219512195

# %%
print(classification_report(y_test,pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.94      0.76       402
#            1       0.62      0.16      0.25       254
#
#     accuracy                           0.64       656
#    macro avg       0.63      0.55      0.51       656
# weighted avg       0.63      0.64      0.56       656

# %%
# confusion Maxtrix
cm2 = confusion_matrix(y_test, pred_dt)
sns.heatmap(cm2/np.sum(cm2), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Creating model object
model_rf = RandomForestClassifier(n_estimators=300,min_samples_leaf=0.16, random_state=42)

# %%
# Training Model
model_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(min_samples_leaf=0.16, n_estimators=300, random_state=42)

# %%
# Making Prediction
pred_rf = model_rf.predict(x_test)

# %%
# Calculating Accuracy Score
rf = accuracy_score(y_test, pred_rf)*100
print(rf)
# Out:
# 61.28048780487805

# %%
print(classification_report(y_test,pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       402
#            1       0.00      0.00      0.00       254
#
#     accuracy                           0.61       656
#    macro avg       0.31      0.50      0.38       656
# weighted avg       0.38      0.61      0.47       656

# %%
# confusion Maxtrix
cm3 = confusion_matrix(y_test, pred_rf)
sns.heatmap(cm3/np.sum(cm3), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Using SVM

# %%
from sklearn.svm import SVC, LinearSVC

# %%
model_svm = SVC(kernel='rbf', random_state = 42)

# %%
model_svm.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
# Making Prediction
pred_svm = model_svm.predict(x_test)

# %%
# Calculating Accuracy Score
sv = accuracy_score(y_test, pred_svm)*100
print(sv)
# Out:
# 61.28048780487805

# %%
print(classification_report(y_test,pred_kn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.82      0.71       402
#            1       0.45      0.24      0.31       254
#
#     accuracy                           0.59       656
#    macro avg       0.54      0.53      0.51       656
# weighted avg       0.56      0.59      0.56       656

# %%
# confusion Maxtrix
cm6 = confusion_matrix(y_test, pred_svm)
sns.heatmap(cm6/np.sum(cm6), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Using AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model_ada = AdaBoostClassifier(learning_rate= 0.002,n_estimators= 205,random_state=42)

# %%
model_ada.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.002, n_estimators=205, random_state=42)

# %%
# Making Prediction
pred_ada = model_ada.predict(x_test)

# %%
# Calculating Accuracy Score
ada = accuracy_score(y_test, pred_ada)*100
print(ada)
# Out:
# 62.95731707317073

# %%
print(classification_report(y_test,pred_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.77       402
#            1       0.79      0.06      0.11       254
#
#     accuracy                           0.63       656
#    macro avg       0.71      0.52      0.44       656
# weighted avg       0.69      0.63      0.51       656

# %%
# confusion Maxtrix
cm7 = confusion_matrix(y_test, pred_ada)
sns.heatmap(cm7/np.sum(cm7), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %%
models = pd.DataFrame({
    'Model':['Logistic Regression', 'Decision Tree', 'Random Forest', 'KNN', 'SVM', 'AdaBoost'],
    'Accuracy_score' :[lg, dt, rf, kn, sv, ada]
})
models
sns.barplot(x='Accuracy_score', y='Model', data=models)

models.sort_values(by='Accuracy_score', ascending=False)
# Out:
#                  Model  Accuracy_score
# 1        Decision Tree       63.719512
# 5             AdaBoost       62.957317
# 3                  KNN       61.737805
# 0  Logistic Regression       61.280488
# 2        Random Forest       61.280488
# 4                  SVM       61.280488

# %% [markdown]
# # Model Optamization / Hyperparameter Tuning

# %% [markdown]
# ## DT HPT

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold


# define models and parameters
dt = DecisionTreeClassifier()
criterion = ["gini", "entropy"]
splitter = ["best", "random"]
min_samples_split = range(1,10)

# define grid search
parameters = dict(criterion=criterion, splitter=splitter, min_samples_split=min_samples_split)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

grid_search_cv_dt = GridSearchCV(estimator=dt, param_grid=parameters, scoring='accuracy' ,cv=cv)

# %%
grid_search_cv_dt.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=1),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'min_samples_split': range(1, 10),
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
print(grid_search_cv_dt.best_params_)
# Out:
# {'criterion': 'gini', 'min_samples_split': 7, 'splitter': 'random'}

# %%
prediction_grid=grid_search_cv_dt.predict(x_test)

# %%
accuracy_score(y_test,prediction_grid)*100
# Out:
# 60.82317073170732

# %%
print("Training Score:",grid_search_cv_dt.score(x_train, y_train)*100)
print("Testing Score:",grid_search_cv_dt.score(x_test, y_test)*100)
# Out:
# Training Score: 88.3969465648855
# Testing Score: 60.82317073170732

# %%
confusion_matrix(y_test, prediction_grid)
# Out:
# array([[267, 135],
#        [122, 132]], dtype=int64)

# %% [markdown]
# ## KN HPT

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# %%
# define models and parameters
model = KNeighborsClassifier()
n_neighbors = range(1, 31)
weights = ['uniform', 'distance']
metric = ['euclidean', 'manhattan', 'minkowski']

# %%
# define grid search
grid = dict(n_neighbors=n_neighbors,weights=weights,metric=metric)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=1)
grid_search_knn = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv)

# %%
grid_search_knn.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=1, n_splits=10, random_state=1),
#              estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': range(1, 31),
#                          'weights': ['uniform', 'distance']})

# %%
grid_search_knn.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 22, 'weights': 'uniform'}

# %%
knn_y_predicted = grid_search_knn.predict(x_test)

# %%
accuracy_score(y_test, knn_y_predicted)*100
# Out:
# 61.737804878048784

# %%
print("Training Score:",grid_search_knn.score(x_train, y_train)*100)
print("Testing Score:",grid_search_knn.score(x_test, y_test)*100)
# Out:
# Training Score: 63.167938931297705
# Testing Score: 61.737804878048784

# %%
confusion_matrix(y_test, knn_y_predicted)
# Out:
# array([[376,  26],
#        [225,  29]], dtype=int64)
